# %%
from PyQt5 import QtCore, QtGui, QtWidgets
from skimage.feature import local_binary_pattern
import cv2 as cv 
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import math

# %%
class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(1181, 896)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.framegambar = QtWidgets.QLabel(self.centralwidget)
        self.framegambar.setGeometry(QtCore.QRect(50, 150, 281, 221))
        self.framegambar.setFrameShape(QtWidgets.QFrame.Box)
        self.framegambar.setText("")
        self.framegambar.setObjectName("framegambar")
        self.buttongambar = QtWidgets.QPushButton(self.centralwidget)
        self.buttongambar.setGeometry(QtCore.QRect(50, 100, 121, 41))
        font = QtGui.QFont()
        font.setFamily("Agency FB")
        font.setPointSize(10)
        self.buttongambar.setFont(font)
        self.buttongambar.setObjectName("buttongambar")
        self.buttonresize = QtWidgets.QPushButton(self.centralwidget)
        self.buttonresize.setGeometry(QtCore.QRect(420, 100, 121, 41))
        font = QtGui.QFont()
        font.setFamily("Agency FB")
        font.setPointSize(10)
        self.buttonresize.setFont(font)
        self.buttonresize.setObjectName("buttonresize")
        self.label = QtWidgets.QLabel(self.centralwidget)
        self.label.setGeometry(QtCore.QRect(310, 10, 1001, 71))
        font = QtGui.QFont()
        font.setFamily("Agency FB")
        font.setPointSize(30)
        font.setBold(False)
        font.setItalic(True)
        font.setWeight(50)
        self.label.setFont(font)
        self.label.setObjectName("label")
        self.groupboxhasil = QtWidgets.QGroupBox(self.centralwidget)
        self.groupboxhasil.setGeometry(QtCore.QRect(790, 550, 231, 101))
        font = QtGui.QFont()
        font.setFamily("Agency FB")
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.groupboxhasil.setFont(font)
        self.groupboxhasil.setObjectName("groupboxhasil")
        self.linehasil = QtWidgets.QLineEdit(self.groupboxhasil)
        self.linehasil.setGeometry(QtCore.QRect(10, 40, 211, 51))
        self.linehasil.setObjectName("linehasil")
        self.buttonLBP = QtWidgets.QPushButton(self.centralwidget)
        self.buttonLBP.setGeometry(QtCore.QRect(50, 390, 191, 41))
        font = QtGui.QFont()
        font.setFamily("Agency FB")
        font.setPointSize(10)
        self.buttonLBP.setFont(font)
        self.buttonLBP.setObjectName("buttonLBP")
        self.frameLBP = QtWidgets.QLabel(self.centralwidget)
        self.frameLBP.setGeometry(QtCore.QRect(50, 440, 281, 221))
        self.frameLBP.setFrameShape(QtWidgets.QFrame.Box)
        self.frameLBP.setText("")
        self.frameLBP.setObjectName("frameLBP")
        self.frameresize = QtWidgets.QLabel(self.centralwidget)
        self.frameresize.setGeometry(QtCore.QRect(420, 150, 281, 221))
        self.frameresize.setFrameShape(QtWidgets.QFrame.Box)
        self.frameresize.setText("")
        self.frameresize.setObjectName("frameresize")
        self.buttonknn = QtWidgets.QPushButton(self.centralwidget)
        self.buttonknn.setGeometry(QtCore.QRect(790, 470, 111, 41))
        font = QtGui.QFont()
        font.setFamily("Agency FB")
        font.setPointSize(10)
        self.buttonknn.setFont(font)
        self.buttonknn.setObjectName("buttonknn")
        self.comboknn = QtWidgets.QComboBox(self.centralwidget)
        self.comboknn.setGeometry(QtCore.QRect(960, 480, 92, 25))
        self.comboknn.setObjectName("comboknn")
        self.comboknn.addItem("")
        self.comboknn.addItem("")
        self.comboknn.addItem("")
        self.comboknn.addItem("")
        self.comboknn.addItem("")
        self.comboknn.addItem("")
        self.comboknn.addItem("")
        self.buttonhisto = QtWidgets.QPushButton(self.centralwidget)
        self.buttonhisto.setGeometry(QtCore.QRect(420, 390, 121, 41))
        font = QtGui.QFont()
        font.setFamily("Agency FB")
        font.setPointSize(10)
        self.buttonhisto.setFont(font)
        self.buttonhisto.setObjectName("buttonhisto")
        self.framehisto = QtWidgets.QLabel(self.centralwidget)
        self.framehisto.setGeometry(QtCore.QRect(420, 440, 281, 221))
        self.framehisto.setFrameShape(QtWidgets.QFrame.Box)
        self.framehisto.setText("")
        self.framehisto.setObjectName("framehisto")
        self.framegreyscale = QtWidgets.QLabel(self.centralwidget)
        self.framegreyscale.setGeometry(QtCore.QRect(790, 150, 281, 221))
        self.framegreyscale.setFrameShape(QtWidgets.QFrame.Box)
        self.framegreyscale.setText("")
        self.framegreyscale.setObjectName("framegreyscale")
        self.buttongreyscale = QtWidgets.QPushButton(self.centralwidget)
        self.buttongreyscale.setGeometry(QtCore.QRect(790, 100, 121, 41))
        font = QtGui.QFont()
        font.setFamily("Agency FB")
        font.setPointSize(10)
        self.buttongreyscale.setFont(font)
        self.buttongreyscale.setObjectName("buttongreyscale")
        self.framegambar.raise_()
        self.buttongambar.raise_()
        self.buttonresize.raise_()
        self.label.raise_()
        self.groupboxhasil.raise_()
        self.buttonLBP.raise_()
        self.frameLBP.raise_()
        self.frameresize.raise_()
        self.buttonknn.raise_()
        self.comboknn.raise_()
        self.buttonhisto.raise_()
        self.framehisto.raise_()
        self.linehasil.raise_()
        self.framegreyscale.raise_()
        self.buttongreyscale.raise_()
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 1181, 31))
        self.menubar.setObjectName("menubar")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)


        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        
    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.buttongambar.setText(_translate("MainWindow", "Pilih Gambar"))
        self.buttonresize.setText(_translate("MainWindow", "Resize"))
        self.label.setText(_translate("MainWindow", "Klasifikasi Jenis Batuan Sedimen"))
        self.groupboxhasil.setTitle(_translate("MainWindow", "Hasil Klasifikasi"))
        self.buttonLBP.setText(_translate("MainWindow", "Local Binary Pattern"))
        self.buttonknn.setText(_translate("MainWindow", "KNN"))
        self.comboknn.setItemText(0, _translate("MainWindow", "1"))
        self.comboknn.setItemText(1, _translate("MainWindow", "2"))
        self.comboknn.setItemText(2, _translate("MainWindow", "3"))
        self.comboknn.setItemText(3, _translate("MainWindow", "4"))
        self.comboknn.setItemText(4, _translate("MainWindow", "5"))
        self.comboknn.setItemText(5, _translate("MainWindow", "6"))
        self.comboknn.setItemText(6, _translate("MainWindow", "7"))
        self.buttonhisto.setText(_translate("MainWindow", "Histogram"))
        self.buttongreyscale.setText(_translate("MainWindow", "Greyscale"))


        self.buttongambar.clicked.connect(self.inputgambar)
        self.buttonresize.clicked.connect(self.konversiresize)
        self.buttongreyscale.clicked.connect(self.konversigreyscale)
    
    #proses input gambar
    def inputgambar(self): 
            fileName, _ = QtWidgets.QFileDialog.getOpenFileName(None, "Select Image", "", "Image Files (*.png *.jpg *jpeg *.bmp)")
            if fileName:
                pixmap = QtGui.QPixmap(fileName)
                pixmap = pixmap.scaled(self.framegambar.width(),self.framegambar.height())
                self.framegambar.setPixmap(pixmap)
                self.framegambar.setAlignment(QtCore.Qt.AlignCenter)
                self.buttonresize.setEnabled(True)
                self.file = fileName
  
            self.image = cv.imread(self.file, cv.IMREAD_ANYCOLOR)
            self.processedImage = self.image.copy()
            self.previewImage = cv.resize(self.processedImage, (0,0))
            self.outputgambar()
                       
          
    def outputgambar(self):
        qFormat = QtGui.QImage.Format_Indexed8
        if len (self.previewImage.shape) == 3:
            if (self.previewImage.shape[2]) == 4:
                qFormat = QtGui.QImage.Format_RGBA8888
            else:
               qFormat = QtGui.QImage.Format_RGB888
        img1 = QtGui.QImage(self.previewImage, self.previewImage.shape[1], self.previewImage.shape[0],self.previewImage.strides[0], qFormat)
        img1 = img1.rgbSwapped()
        
                
        self.framegambar.setPixmap(QtGui.QPixmap.fromImage(img1))
        self.framegambar.setAlignment(QtCore.Qt.AlignHCenter|QtCore.Qt.AlignVCenter)
    
    
    def konversiresize(self):          
         self.processedImage = self.image.copy()
         self.previewImage = cv.resize(self.processedImage, (128,128))   
         self.outputresize()
   
    
    def outputresize(self):
        qFormat = QtGui.QImage.Format_Indexed8
        if len (self.previewImage.shape) == 3:
            if (self.previewImage.shape[2]) == 4:
                qFormat = QtGui.QImage.Format_RGBA8888
            else:
               qFormat = QtGui.QImage.Format_RGB888
        img1 = QtGui.QImage(self.previewImage, self.previewImage.shape[1], self.previewImage.shape[0],self.previewImage.strides[0], qFormat)
        img1 = img1.rgbSwapped()
               
        
        self.frameresize.setPixmap(QtGui.QPixmap.fromImage(img1))
        self.frameresize.setAlignment(QtCore.Qt.AlignHCenter|QtCore.Qt.AlignVCenter)
        self.buttongreyscale.setEnabled(True)
        
   
    def konversigreyscale(self):
        self.gray = cv.cvtColor(self.previewImage, cv.COLOR_BGR2GRAY)
        self.previewgray = cv.resize(self.gray,(128,128))
        self.previewgray= self.gray
        self.outputgreyscale()
        
        
    def outputgreyscale(self):
        qFormat = QtGui.QImage.Format_Indexed8
        if len (self.previewgray.shape) == 3:
            if (self.previewgray.shape[2]) == 4:
                qFormat = QtGui.QImage.Format_RGBA8888
            else:
                qFormat = QtGui.QImage.Format_RGB888
        self.img1 = QtGui.QImage(self.previewgray, self.previewgray.shape[1], self.previewgray.shape[0], self.previewgray.strides[0], qFormat)
        self.img1 = self.img1.rgbSwapped()
        self.framegreyscale.setPixmap(QtGui.QPixmap.fromImage(self.img1))
        self.framegreyscale.setAlignment(QtCore.Qt.AlignHCenter|QtCore.Qt.AlignVCenter)
        self.LBP.setEnabled(True)
    def outputocalbinarypattern(self):
        qFormat = QtGui.QImage.Format_Indexed8
        if len (self.previewgray.shape) == 3:
            if (self.previewgray.shape[2]) == 4:
                qFormat = QtGui.QImage.Format_RGBA8888
            else:
                qFormat = QtGui.QImage.Format_RGB888
        self.img1 = QtGui.QImage(self.previewgray, self.previewgray.shape[1], self.previewgray.shape[0], self.previewgray.strides[0], qFormat)
        self.img1 = self.img1.rgbSwapped()
        self.frameLBP.setPixmap(QtGui.QPixmap.fromImage(self.img1))
        self.frameLBP.setAlignment(QtCore.Qt.AlignHCenter|QtCore.Qt.AlignVCenter)
        self.buttonhisto.setEnabled(True)
        



if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3426: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pandas as pd
import numpy as np

from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression, Ridge, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.kernel_ridge import KernelRidge
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
import string
import math
import sys

# disable warnings:
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
data = pd.read_csv("panen.csv")

# %%
data
# Out:
#     Tipe Kotak Indukan  Jumlah Indukan  Banyak Indukan/kg Tipe Kotak UK  \
# 0                    A               6               1.00             A
# 1                    B               9               0.80             A
# 2                    B               4               0.80             B
# 3                    B               1               1.00             B
# 4                    B               1               1.00             B
# ..                 ...             ...                ...           ...
# 104                  A               1               1.00             A
# 105                  B               7               0.85             A
# 106                  B               3               0.85             C
# 107                  B               6               1.00             C
# 108                  B               6               1.00             D
#
#      Jumlah UK  Hasil Panen/kg
# 0           15            30.0
# 1           15            30.0
# ...

# %%
data2 = pd.read_csv("suhu.csv")

# %%
data2
# Out:
#      suhu  suhu luar ruangan  hasil
# 0      32                 33      1
# 1      27                 32      0
# 2      35                 31      1
# 3      31                 29      1
# 4      35                 29      1
# ..    ...                ...    ...
# 289    31                 31      1
# 290    34                 30      1
# 291    34                 34      1
# 292    28                 29      1
# 293    30                 32      1
#
# [294 rows x 3 columns]

# %%
new = data2[data2.hasil != 0]

# %%
new
# Out:
#      suhu  suhu luar ruangan  hasil
# 0      32                 33      1
# 2      35                 31      1
# 3      31                 29      1
# 4      35                 29      1
# 6      35                 32      1
# ..    ...                ...    ...
# 289    31                 31      1
# 290    34                 30      1
# 291    34                 34      1
# 292    28                 29      1
# 293    30                 32      1
#
# [261 rows x 3 columns]

# %%
for column in suhu.columns:
    print(column, len(suhu[column].unique()))
# Out:
# suhu 9
# suhu luar ruangan 6
# hasil 1

# %%
new.to_csv('newsuhu.csv',index=False)

# %%
suhu = pd.read_csv("newsuhu.csv")

# %%
suhu
# Out:
#      suhu  suhu luar ruangan  hasil
# 0      32                 33      1
# 1      35                 31      1
# 2      31                 29      1
# 3      35                 29      1
# 4      35                 32      1
# ..    ...                ...    ...
# 256    31                 31      1
# 257    34                 30      1
# 258    34                 34      1
# 259    28                 29      1
# 260    30                 32      1
#
# [261 rows x 3 columns]

# %%
df = pd.concat([suhu, data])

# %%
df
# Out:
#      suhu  suhu luar ruangan  hasil Tipe Kotak Indukan  Jumlah Indukan  \
# 0    32.0               33.0    1.0                NaN             NaN
# 1    35.0               31.0    1.0                NaN             NaN
# 2    31.0               29.0    1.0                NaN             NaN
# 3    35.0               29.0    1.0                NaN             NaN
# 4    35.0               32.0    1.0                NaN             NaN
# ..    ...                ...    ...                ...             ...
# 104   NaN                NaN    NaN                  A             1.0
# 105   NaN                NaN    NaN                  B             7.0
# 106   NaN                NaN    NaN                  B             3.0
# 107   NaN                NaN    NaN                  B             6.0
# 108   NaN                NaN    NaN                  B             6.0
#
#      Banyak Indukan/kg Tipe Kotak UK  Jumlah UK  Hasil Panen/kg
# ...

# %%
df.isnull().sum()
# Out:
# suhu                  0
# suhu luar ruangan     0
# hasil                 0
# Tipe Kotak Indukan    0
# Jumlah Indukan        0
# Banyak Indukan/kg     0
# Tipe Kotak UK         0
# Jumlah UK             0
# Hasil Panen/kg        0
# dtype: int64

# %%
for column in df.columns:
    print(column, len(df[column].unique()))
# Out:
# suhu 9
# suhu luar ruangan 6
# hasil 1
# Tipe Kotak Indukan 3
# Jumlah Indukan 14
# Banyak Indukan/kg 15
# Tipe Kotak UK 4
# Jumlah UK 18
# Hasil Panen/kg 36

# %%
df.fillna( method ='bfill', inplace = True)
df
# Out:
#      suhu  suhu luar ruangan  hasil Tipe Kotak Indukan  Jumlah Indukan  \
# 0    32.0               33.0    1.0                  A             6.0
# 1    35.0               31.0    1.0                  A             6.0
# 2    31.0               29.0    1.0                  A             6.0
# 3    35.0               29.0    1.0                  A             6.0
# 4    35.0               32.0    1.0                  A             6.0
# ..    ...                ...    ...                ...             ...
# 104  30.0               32.0    1.0                  A             1.0
# 105  30.0               32.0    1.0                  B             7.0
# 106  30.0               32.0    1.0                  B             3.0
# 107  30.0               32.0    1.0                  B             6.0
# 108  30.0               32.0    1.0                  B             6.0
#
#      Banyak Indukan/kg Tipe Kotak UK  Jumlah UK  Hasil Panen/kg
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      suhu  suhu luar ruangan  hasil Tipe Kotak Indukan  Jumlah Indukan  \
# 0    32.0               33.0    1.0                  A             6.0
# 1    35.0               31.0    1.0                  A             6.0
# 2    31.0               29.0    1.0                  A             6.0
# 3    35.0               29.0    1.0                  A             6.0
# 4    35.0               32.0    1.0                  A             6.0
# ..    ...                ...    ...                ...             ...
# 103  30.0               32.0    1.0                  B            14.0
# 105  30.0               32.0    1.0                  B             7.0
# 106  30.0               32.0    1.0                  B             3.0
# 107  30.0               32.0    1.0                  B             6.0
# 108  30.0               32.0    1.0                  B             6.0
#
#      Banyak Indukan/kg Tipe Kotak UK  Jumlah UK  Hasil Panen/kg
# ...

# %%
for column in df.columns:
    print(column, len(df[column].unique()))
# Out:
# suhu 9
# suhu luar ruangan 6
# hasil 1
# Tipe Kotak Indukan 3
# Jumlah Indukan 14
# Banyak Indukan/kg 15
# Tipe Kotak UK 4
# Jumlah UK 18
# Hasil Panen/kg 36

# %%
df = df.drop(['hasil'], axis=1)

# %%
df
# Out:
#      suhu  suhu luar ruangan Tipe Kotak Indukan  Jumlah Indukan  \
# 0    32.0               33.0                  A             6.0
# 1    35.0               31.0                  A             6.0
# 2    31.0               29.0                  A             6.0
# 3    35.0               29.0                  A             6.0
# 4    35.0               32.0                  A             6.0
# ..    ...                ...                ...             ...
# 103  30.0               32.0                  B            14.0
# 105  30.0               32.0                  B             7.0
# 106  30.0               32.0                  B             3.0
# 107  30.0               32.0                  B             6.0
# 108  30.0               32.0                  B             6.0
#
#      Banyak Indukan/kg Tipe Kotak UK  Jumlah UK  Hasil Panen/kg
# 0                 1.00             A       15.0            30.0
# 1                 1.00             A       15.0            30.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 108
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   suhu                150 non-null    float64
#  1   suhu luar ruangan   150 non-null    float64
#  2   Tipe Kotak Indukan  150 non-null    object
#  3   Jumlah Indukan      150 non-null    float64
#  4   Banyak Indukan/kg   150 non-null    float64
#  5   Tipe Kotak UK       150 non-null    object
#  6   Jumlah UK           150 non-null    float64
#  7   Hasil Panen/kg      150 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 10.5+ KB

# %%
sns.boxplot(df['Jumlah Indukan'])

# %%
print('Skew for Kerugian Capital:',df['Banyak Indukan/kg'].skew())
# Out:
# Skew for Kerugian Capital: -2.5397385940229316

# %%
IQR = df['Banyak Indukan/kg'].quantile(0.75) - df['Banyak Indukan/kg'].quantile(0.25)
upper_bound = df['Banyak Indukan/kg'].quantile(0.75) + 3*IQR
# for train and test sets convert all values in column Fair where age is more than upper_bound to upper_bound:
df.loc[df['Banyak Indukan/kg'] >upper_bound, 'Banyak Indukan/kg'] = upper_bound 

max(df['Banyak Indukan/kg'])
# Out:
# 1.0

# %%
le= LabelEncoder()
df['Tipe Kotak Indukan'] =  le.fit_transform(df['Tipe Kotak Indukan'])
df['Tipe Kotak UK'] = le.fit_transform(df['Tipe Kotak UK'])
df['Tipe Kotak UK']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 103    0
# 105    0
# 106    2
# 107    2
# 108    3
# Name: Tipe Kotak UK, Length: 150, dtype: int32

# %%
df
# Out:
#      suhu  suhu luar ruangan  Tipe Kotak Indukan  Jumlah Indukan  \
# 0    32.0               33.0                   0             6.0
# 1    35.0               31.0                   0             6.0
# 2    31.0               29.0                   0             6.0
# 3    35.0               29.0                   0             6.0
# 4    35.0               32.0                   0             6.0
# ..    ...                ...                 ...             ...
# 103  30.0               32.0                   1            14.0
# 105  30.0               32.0                   1             7.0
# 106  30.0               32.0                   1             3.0
# 107  30.0               32.0                   1             6.0
# 108  30.0               32.0                   1             6.0
#
#      Banyak Indukan/kg  Tipe Kotak UK  Jumlah UK  Hasil Panen/kg
# 0                 1.00              0       15.0            30.0
# ...

# %%
plt.figure(figsize=(17,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df.corr(),linewidths=0.1,vmax=1.0, 
            square=True,linecolor='white', annot=True)

# %%
plt.savefig('foo.png')

# %%
drop_col = ['Tipe Kotak UK', 'Tipe Kotak Indukan']
df = df.drop(drop_col, axis=1)

# %%
df
# Out:
#      suhu  suhu luar ruangan  Tipe Kotak Indukan  Jumlah Indukan  \
# 0    32.0               33.0                   0             6.0
# 1    35.0               31.0                   0             6.0
# 2    31.0               29.0                   0             6.0
# 3    35.0               29.0                   0             6.0
# 4    35.0               32.0                   0             6.0
# ..    ...                ...                 ...             ...
# 103  30.0               32.0                   1            14.0
# 105  30.0               32.0                   1             7.0
# 106  30.0               32.0                   1             3.0
# 107  30.0               32.0                   1             6.0
# 108  30.0               32.0                   1             6.0
#
#      Banyak Indukan/kg  Tipe Kotak UK  Jumlah UK  Hasil Panen/kg
# 0                 1.00              0       15.0            30.0
# ...

# %%
X = df.drop(columns= ['Hasil Panen/kg'])
Y = df['Hasil Panen/kg']

# %%
sns.clustermap(X.corr(),linewidths=0.1,vmax=1.0, 
            square=True,linecolor='white')

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
y_test
# Out:
# 71      7.5
# 19      8.5
# 61     30.0
# 64     24.0
# 7      30.0
# 57     21.0
# 105    30.0
# 43     16.0
# 33     13.5
# 28      7.0
# 91      2.0
# 8       7.0
# 30     37.5
# 11     22.5
# 20      9.5
# 87     30.0
# 35     46.0
# 47     17.0
# 2      11.5
# 19     30.0
# 78     40.0
# 23     10.5
# 31     30.0
# 8      30.0
# 83     42.0
# 29     30.0
# 1      30.0
# 54      9.0
# 50     10.5
# 35     30.0
# 94     25.5
# 41      2.0
# 37     30.0
# 84     42.0
# 89      6.5
# 16     12.0
# 21     30.0
# 40      4.0
# Name: Hasil Panen/kg, dtype: float64

# %%
sns.pairplot(X)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
pred = reg.predict(x_test)
pred
# Out:
# array([ 6.67560366, 12.48080021, 29.22578898, 32.7680195 , 28.90431138,
#        17.07886897, 29.93261028, 16.73067099, 21.75394101,  4.33340699,
#         7.83896113, 12.48080021, 40.83072406, 24.11436899, 14.63431976,
#        28.03782489, 43.79521843, 14.89068922, 13.8979214 , 28.87237834,
#        24.85765147, 16.5589902 , 29.61113267, 28.10169097, 22.5880915 ,
#        28.80851226, 30.02613792,  5.83499336, 17.25929327, 30.73523069,
#        14.62140015,  4.81862556, 28.8404453 , 28.78069753, 12.76442205,
#        16.24034155, 28.00589185,  3.79579795])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

def rmse(y_true, y_pred):
    return mean_squared_error(y_true,y_pred)**0.5

# %%
df.describe()
# Out:
#              suhu  suhu luar ruangan  Tipe Kotak Indukan  Jumlah Indukan  \
# count  150.000000         150.000000           150.00000      150.000000
# mean    30.493333          31.753333             0.70000        5.160000
# std      1.482546           0.975792             0.79216        2.785581
# min     27.000000          29.000000             0.00000        1.000000
# 25%     30.000000          32.000000             0.00000        3.000000
# 50%     30.000000          32.000000             0.00000        6.000000
# 75%     30.000000          32.000000             1.00000        6.000000
# max     35.000000          34.000000             2.00000       14.000000
#
#        Banyak Indukan/kg  Tipe Kotak UK   Jumlah UK  Hasil Panen/kg
# count         150.000000     150.000000  150.000000      150.000000
# mean            6.119600       0.706667    9.220000       19.988333
# std            59.116903       0.930805    5.646012       11.560475
# ...

# %%
x_test
# Out:
#      suhu  suhu luar ruangan  Tipe Kotak Indukan  Jumlah Indukan  \
# 71   30.0               32.0                   2             2.0
# 19   30.0               32.0                   1             3.0
# 61   32.0               31.0                   0             6.0
# 64   30.0               32.0                   0            10.0
# 7    33.0               33.0                   0             6.0
# 57   30.0               32.0                   0             8.0
# 105  32.0               29.0                   0             6.0
# 43   30.0               32.0                   1             9.0
# 33   30.0               32.0                   0             5.0
# 28   30.0               32.0                   1             1.0
# 91   30.0               32.0                   2             4.0
# 8    30.0               32.0                   1             3.0
# 30   30.0               32.0                   1            13.0
# ...

# %%
-
# Out:
# Saved file: hasilpanen1.csv

# %%
hasilpanen = pd.read_csv("hasilpanen1.csv")
hasilpanen
# Out:
#     Jumlah Kotak  Tipe Kotak Indukan  Tipe Kotak UK  Jumlah Kotak UK  Suhu  \
# 0            2.0                   2              1              4.0  30.0
# 1            3.0                   1              1              6.0  30.0
# 2            6.0                   0              0             15.0  32.0
# 3           10.0                   0              0             14.0  30.0
# 4            6.0                   0              0             15.0  33.0
# 5            8.0                   0              0              1.0  30.0
# 6            6.0                   0              0             15.0  32.0
# 7            9.0                   1              0              2.0  30.0
# 8            5.0                   0              1             10.0  30.0
# 9            1.0                   1              0              1.0  30.0
# 10           4.0                   2              3              2.0  30.0
# ...
